# %% [markdown]
# # 2244 ME 2061 Reduced Order Modeling for Engineering
#
# ---
#
# ## Table of Contents
#
# <span style="font-size: 1.25em">1. [Syllabus](#Syllabus)</span>
#
# <span style="font-size: 1.25em">2. [20240111 lecture notes](#20240111-lecture-notes)</span>
#
# <span style="font-size: 1.25em">3. [20240118 lecture notes](#20240118-lecture-notes)</span>

# %% [markdown]
# ## Syllabus

# %% [markdown]
# ### Lecture information
#
# All lectures will be conducted in class from 4:30pm - 7:00 pm on Thursday.  There will not be any virtual lectures.  The lectures will not be recorded either.  Lecture notes will be posted to Canvas after each lecture.
#
# ### Course description and objectives
#
# This course will provide an introduction to dimension-reduction techniques and reduced order modeling.  The course covers the mathematical foundation of all the techniques discussed and includes a diverse set of applications.  In particular, the course covers the utility of dimension reduction in the diagnostics of complex data, deterministic and stochastic reduced order modeling and their applications in optimization and uncertainty quantification.
#
# ### Topics
#
# The topics covered in this course are:
#
# #### Preliminaries
#
# 1. Introduction to dimension reduction and reduced-order modeling.
#
# 2. Review of relevant subjects from linear algebra: linear independence, matrix rank, second norm and Frobenius norms, inner product, angle, orthogonal projection, and oblique projection.
#
# 3. Finite-dimensional (vectors) versus infinite-dimensional (functions) representations.
#
# 4. Bases: piece-wise linear, monomials, spectral polynomials, and Fourier.
#
# 5. Interpolation, regression, and projection.
#
# 6. Discretization and approximating a partial differential equation with a system of ordinary differential equations.
#
# #### Dimension reduction with sigular value decomposition (SVD)
#
# 1. SVD and optimality
#
# 2. Low-rank approximation with SVD.
#
# 3. Different interpretations of SVD.
#
# 4. Functional SVD.
#
# 5. Applications.
#
# #### Reduced-order modeling of vector differential equations
#
# 1. Proper-orthogonal decomposition (POD)
#
# 2. POD-Galerkin reduced order models.
#
# 3. Linear time-dependent partial differential equations.
#
# 4. Nonlinear time-dependent partial differential equations.
#
# 5. Examples: transient conduction, linear advection, and Burgers.
#
# #### Sparse sampling
#
# 1. Motivation: computational cost issues in nonlinear reduced-order modeling.
#
# 2. The direct empirical interpolation method (DEIM) and QDEIM.
#
# 3. CUR low-rank approximation.
#
# 4. Application: Sensor placement and field reconstruction from sparse measurements.
#
# #### Advanced topics: On-the-fly low-rank approximation with time-dependent bases
#
# 1. Matrix differential equations (MDEs).
#
# 2. Low-rank approximation of MDEs with time-dependent bases.
#
# 3. Dynamical low-rank approximation and its variants.
#
# 4. Oblique projection for the low-rank approximation.
#
# ### Evaluation
#
# The grading policy is as follows:
#
# 1. Quiz: Plickers multiple-choice questions (10%).
#
# 2. Homework Assignments (60%).
#
# 3. Final Project: Includes a computer project, final report and a presentation (30%).
#
# All assessments will be submitted electronically on the [Canvas site][1].  Late submissions will be penalized.
#
# ### Office Hours
#
# Office hours will be conducted via [Zoom][2] on Mondays from 3:30pm - 5:00pm. To avoid having multiple students on the same Zoom session, please contact [Dr. Babaee][3].
#
# ### Textbook
#
# The following textbook listed below is the primary reference for this course.  You will not be required to read any of the books in their entirety.
#
# 1. [Steve Brunton and J. Nathan and J. Nathan Kutz, Data-Driven Science and Engineering, Cambridge University Press, Second Edition, 2022.][4]
#
# ### Other suggested references
#
# 1. [G.t Strang, Linear Algebra and Learning from Data.  Cambridge Press, 2019.][5]
# <br>
# <br>
# 2. [S. Theodoridis, Machine Learning, A Bayesian and Optimization Perspective, 2nd Edition, Elsevier, 2020.][6]
# <br>
# <br>
# 3. [P. Holmes, J. L. Lumley, and G. Berkooz, C. W. Rowley, Turbulence, Coherent Structures, Dynamical Systems and Symmetry, Second Edition, Cambridge: Cambridge University Press, 2012.][7]
# <br>
# <br>
# 4. [J. N. Kutz, S. Brunton, B. W. Brunton, J. L. Proctor, Dynamic Mode Decomposition, SIAM, 2016.][8]
#
# [1]: <https://canvas.pitt.edu/courses/255837> "Canvas Site"
#
# [2]: <https://pitt.zoom.us/j/6177518304> "Office hours Zoom link"
#
# [3]: <mailto:h.babaee@pitt.edu> "h.babaee@pitt.edu"
#
# [4]: <https://www.databookuw.com> "Data-Driven Science and Engineering"
#
# [5]: <https://math.mit.edu/~gs/linearalgebra/ila5/indexila5.html> "Strang LA"
#
# [6]:<https://github.com/Honei/bookshelf/blob/master/Machine%20Leraning/Machine_Learning_A_Bayesian_and_Optimization_Perspective.pdf> "GitHub for Machine Learning Book"
#
# [7]: <https://www.cambridge.org/core/books/turbulence-coherent-structures-dynamical-systems-and-symmetry/4D353229751BBB24C8C266B4714CA9F2> "Link to buy book"
#
# [8]: <https://epubs.siam.org/doi/book/10.1137/1.9781611974508> "Link to buy book"

# %% [markdown]
# #  20240111 lecture notes

# %% [markdown]
# ### Linear independence
#
# If a set of vectors are not a linear combination of any of the vectors in the set, then the system is linearly independent; otherwise the system is linearly dependent.
#
# **Dimension**: The minimum number of vectors needed to represent the space.
#
# **Degrees of freedom**: The minimum number of elements needed to represent the space (e.g., elements in a vector and scaling factors).
#
# $$
# \mathbf{u_1} =
# \begin{bmatrix}
# 1\\
# 2\\
# 3\\
# \end{bmatrix}
# \quad
# \mathbf{u_2} =
# \begin{bmatrix}
# 0\\
# 1\\
# 2\\
# \end{bmatrix}
# \quad
# \mathbf{u_3} =
# \begin{bmatrix}
# 2\\
# 4\\
# 6.001\\
# \end{bmatrix}
# $$
#
# Since these are very close to linearly dependent there are methods with SVD to approximate this system of equations as linearly dependent.
#
# ### Inner product
#
# Anything that comes out of an inner product is a scaler.  Remember the "dot product" is just an inner product but all inner products are not "dot products".  See Mathematics of Data-enabled engineering notes for inner product notes.
#
# #### Weighted inner product
#
# transcribe from notes
#
# #### Length
#
# transcribe from notes
#
# $$
# \lVert \mathbf{u} \rVert = \langle \mathbf{u}, \mathbf{u} \rangle^{1/2}
# $$
#
# #### Angle
#
# $$
# \cos{\alpha} = \frac{\langle \mathbf{u}, \mathbf{v} \rangle}{\lVert \mathbf{u} \rVert \lVert \mathbf{v} \rVert}
# $$
#
# #### Orthgonality
#
# *u* and *v* are orthogonal: $\langle \mathbf{u}, \mathbf{v} \rangle = 0$ which implies $\cos{\alpha} = 0$ which implies $\alpha = 90$
#
# #### Orthonormality
#
# $\langle \mathbf{u}, \mathbf{v} \rangle$ are orthonormal: $\langle \mathbf{u}, \mathbf{v} \rangle = 0$ where $\lVert \mathbf{u} \rVert = \lVert \mathbf{v} \rVert = 1$
#
# ### Discrete space vs. infinite space
#
# #### Finite dimensional space
#
# Given:
#
# $$
# \mathbf{u} =
# \begin{bmatrix}
# u_1\\
# u_2\\
# \vdots\\
# u_N
# \end{bmatrix}
# $$
#
# *Inner product*
#
# $$
# \langle \mathbf{u}, \mathbf{v} \rangle = \mathbf{u}^\intercal \mathbf{v}
# $$
#
# #### Infinite dimensional space
#
# > <span style="font-size: 1.25em"> *A function is a vector with infintely many entries...*</span>
#
# Given:
#
# $$
# \text{u}(x) = \exp(-(x-1)^2)
# $$

# %%
# import necessary modules
import numpy as np
import matplotlib.pyplot as plt

# define domain and range
x = np.arange(0, 5, 0.001)
u = np.exp(-(x-1)**2)

# map the domain to the range
plt.plot(x, u)
plt.title("u(x) vs. x")
plt.xlabel("x")
plt.ylabel("u(x)")
plt.show()

# %% [markdown]
# *Inner product*
#
# $$
# \langle \text{u}(x), \text{v}(x) \rangle = \int\limits_a^b\text{u}(x)\text{v}(x)\,dx
# $$
#
# *Norm*
#
# $$
# \lVert \text{u}(x) \rVert = \langle \text{u}(x), \text{u}(x) \rangle^{1/2} = \Biggl[\int\limits_a^b\text{u}(x)\text{v}(x)\,dx)\Bigg]^{1/2}
# $$
#
# *Example: Orthogonal functions*
#
# $$
# \langle \sin{x}, \cos{x} \rangle = \int\limits_{-\pi}^\pi\sin{x}\cos{x}\,dx = 0
# $$
#
# #### Matrices
#
# Given:
#
# $$
# \mathbf{A}|_{\text{nxm}} \quad \mathbf{B}|_{\text{nxm}}
# $$
#
# *Inner product*
#
# $$
# \langle \mathbf{A}, \mathbf{B} \rangle = \sum_{\text{j}=1}^\infty\sum_{\text{i}=1}^\infty A_{\text{ij}}B_{\text{ij}}
# $$
#
# *Norm*
#
# Frobenius Norm: $\lVert \mathbf{A} \rVert_{F} := \Big[\langle \mathbf{A}, \mathbf{A} \rangle\Big]^{1/2}$
#
# *I asked Dr. Baebaee the following and this was his resposne*
#
# > **Cunningham**
# <br>
# ...Last question is just on nomenclature.  For instance, the definition of orthonormality is $\langle \mathbf{u}, \mathbf{v}\rangle$ are orthonormal iff $\langle \mathbf{u}, \mathbf{v} \rangle = 0$ where $\lVert \mathbf{u} \rVert = \lVert \mathbf{v} \rVert = 1$.  Is $\lVert \mathbf{u} \rVert$ the L2 Norm or is it more general and just $\langle \mathbf{u}, \mathbf{u} \rangle^{1/2}$ ?
# <br>
# <br>
# **Dr. Baebaee**
# <br>
# ...For vectors and functions, $\langle \mathbf{u}, \mathbf{u} \rangle^{1/2}$ is the L2 norm.  But if you have matrices, it is the Frobenius norm...
#
# ### Projections
#
# > <span style="font-size: 1.25em"> *Think of different projects as different light sources you are shining it onto the vector to get a shadow on the plane.*</span>
#
# *I asked Dr. Baebaee the following and this was his response*
#
# > **Cunningham**
# <br>
# ...What I don’t understand is how the resulting projection is the same regardless of what projection method is used  (e.g., orthogonal, oblique).  I may be reading into the analogy too much, but wouldn’t the intensity/contrast/whatever-you-want-to-call-it of the shadow be different?  And if that doesn’t matter what’s the point of doing different projection methods?
# <br>
# <br>
# **Dr. Baebaee**
# <br>
# ...The resulting projection is **not** the same for different projections. If you change the projection you get different results...

# %% [markdown]
# # 20240118 lecture notes

# %% [markdown]
# ### Linear Independence

# %%
# input necessary modules
import matplotlib.pyplot as plt

# vectors
x = [0, 0]  # x-components of vector tails
y = [0, 0]  # y-components of vector tails
u = [1, -1] # x-components of vector tips
v = [1, -1] # y-components of vector tips

plt.quiver(x, y, u, v, angles = 'xy', units = 'xy', scale = 1)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.show()
# Out:
# C:\Users\jjcun\anaconda3\Lib\site-packages\matplotlib\quiver.py:603: RuntimeWarning: invalid value encountered in divide
#   lengths = np.hypot(*dxy.T) / eps

# %% [markdown]
# See notes for diagram *put it here*
#
# $$
#   v_1  = \alpha{}v_2
# $$
#
# $$
# \alpha_{1}v_1 + \alpha_{2}v_2 = \mathbf{0}
# $$
#
# $\alpha_1$ and $\alpha_2$ are scalers
#
# $$
# v_1 = \frac{-\alpha_2}{\alpha_1}v_2
# $$
#
# But for a linear independent system the only way to satisfy this equation is if $\alpha_1$ and $\alpha_2$ is equal to 0
#
# You can generalize this...
#
# The set of vectors {$v_1\text{, }v_2\text{, }\ldots\text{, }v_n$} are linearly independent if and only if
#
# $$
# \alpha_{1}v_1 + \ldots + \alpha_{n}v_n = \vec{0}
# $$
#
# The only solution to this equation is $\alpha_1 = \ldots = \alpha_n = 0$

# %% [markdown]
# *put R2 plot here*
#
# If orthogonal then you know they are independent
#
# If the set of vectors {$v_1\text{, }\ldots\text{, }v_n$} are orthogonal then, $v_{i}^{T}v_{j} = 0\text{, } i \neq j$
#
# > I think that it's an easier way to show linear independence, but clarify
#
# #### Space & Span
#
# the space spanned by vectors {$v_1\text{, }\ldots\text{, }v_n$}, this means the space of vectors in the form of $u = \alpha_{1}v_1 + \ldots + \alpha_{n}$ where $\alpha_{i} \in \mathbb{R}$
#
# ##### Example
#
# The space spanned by $\mathbb{R}^{2}$
# $$
# v_1 =
# \begin{bmatrix}
#   1 \\
#   0
# \end{bmatrix}
# \qquad
# v_2 =
# \begin{bmatrix}
#   0 \\
#   1
# \end{bmatrix}
# $$
#
# Suppose
# $$
# u =
# \begin{bmatrix}
#   3 \\
#   4
# \end{bmatrix}
# = 3v_1 + 4 v_2
# $$
#
#
# ##### Example
#
# The space spanned by $\mathbb{R}^{2}$
#
# $$
# v_1 =
# \begin{bmatrix}
#   1 \\
#   1
# \end{bmatrix}
# \qquad
# v_2 =
# \begin{bmatrix}
#   -1 \\
#   3
# \end{bmatrix}
# $$
#
# ##### Example
#
# The space spanned by these two vectors is a line and you can find that line.
#
# $$
# v_1 =
# \begin{bmatrix}
#   1 \\
#   2
# \end{bmatrix}
# \qquad
# v_2 =
# \begin{bmatrix}
#   -4 \\
#   -8
# \end{bmatrix}
# $$
#
# #### Dimension
#
# The dimension of the space spanned by {$v_1\text{, }\ldots\text{, }v_n$} is the minimum number of vectors that span the same space as {$v_1\text{, }\ldots\text{, }v_n$}.
#
# ##### Example
#
# >if you have 3 dimensional vectors that span a plane than the degrees of freedom would be the two vectors needed to span the space + the three components to make the vector so 5, *but* the dimension would be 2 (each indpendent vector)
#
# Given:
#
# $$
# v_1 =
# \begin{bmatrix}
#   1 \\
#   2
# \end{bmatrix}
# \qquad
# v_2 =
# \begin{bmatrix}
#   -4 \\
#   -8
# \end{bmatrix}
# $$
#
# > Check the ratios to see if they are the same and if they are then you know they are aligned, if not then at least you are in R2
#
# $$
# v_1 =
# \begin{bmatrix}
#   1 \\
#   0 \\
#   -2
# \end{bmatrix}
# \qquad
# v_2 =
# \begin{bmatrix}
#   3 \\
#   4 \\
#   -1
# \end{bmatrix}
# \qquad
# \begin{bmatrix}
#   4 \\
#   4 \\
#   -3
# \end{bmatrix}
# $$
#
# Since $v_1 + v_2 = v_3$ the dimension is 2
#
# **This is the whole point of the class... dimension reduction**
#
# #### Projectors
#
# Orthogonal projection is orthogonal to the space.  Projects takes a vector and projects it to a space.
#
# if $\vec{u}\in\mathbb{R}^{n}$ then $\vec{u} = P\vec{v} \in \mathbb{R}^{n}$ and generates another vector $\in \mathbb{R}^{n}$ say $\vec{v}$
#
# *insert graph from notes here*
#
# **Note different projects (e.g., orthogonal vs. oblique) produce different projections for the same vector**
#
# Not any matrix is a projector but for this context a matrix conforming to special restrictions is an $n$ by $n$ matrix
#
# $P_{n\times{}n}\qquad P(pv) = (PP)v = P^{2}v$ using a matrix identity and this means that this should be equal to $Pv$
#
# A projector is a matrix where if you do $P^{2}$ you get $P$.
#
# > Ask him if we can get the legs of the triangle created by the projection to create an orthogonal basis
#
# Projector: The matrix $P_{n\times n}$ is a projector if $P^{2} = P$.  That's it.
#
# What is complementary projector?  That's the left over leg of the triangle.
#
# $$
# w = (I - P)v
# $$
#
# Need to show this is a projector so show $(I-P)^{2} = I - P$
#
# $$
# \begin{align}
# (I - P)(I - P) & =\\
# & = I - P - P + P^{2}\\
# & = I - 2P + P^{2} \\
# & = I - 2P + P \\
# & = I - P
# \end{align}
# $$
#
# > Go over how he got this
#
# ##### Example
#
# If $U_{n\times r} = {u_1\text{, }\ldots\text{, }v_r}\quad n \gt r$ and columns of $U$ are a set of orthonormal vectors, then $P = UU^{T}$ is a projector.
#
# $$
# \langle u_{i}\text{, }u_{j}\rangle = u_{i}^{T}u_{j} = \delta_{ij} =
# \begin{cases}
#   1 & i=j \\
#   0 & i\neq j
# \end{cases}
# $$
#
# *Got LaTeX heavy, copy from notes*
#
# End result is $U^{T}U = I_{r\times r}$.
#
# Suppose $n = 1000$ and $r = 5$ then $P = (UU^{T})_{n\times n}$. This is the outer product.
#
# But $I = (U^{T}U)_{r\times r}$. This is the inner product.
#
# *see his notes on how he proves this is a projector*
#
# IF the inner product of u and w is 0 then we have an orthogonal projector and this is only possible if the matrix P is symmetric.
#
# #### Orthogonal Projector
#
# $P_{n\times n}$ is an orthgonal projector if:
#
# $$
# \begin{cases}
#   P^{2} = P \\
#   P^{T} = P
# \end{cases}
# $$
#
# SHow this - it's a homework problem.  SHow this is only true is P is symmetric that is $P^{T} = P$:
#
# $$
# (Pv)^{T}((I - P)v) = 0
# $$
#
# A more generic statement is the follow:
#
# WE can show that the inner product of blah blah:
#
# $$
# \langle Pv\text{, } (I - P)v\rangle = 0
# $$
#
# You can think of w as the error in the projection because that's what we are missing in the projection.
#
# #### Singular Value Decomposition
#
# $A_{n\times m} = U_{n \times m}\Sigma_{m \times m} V^{T}_{m \times m}$
#
# Assume $n \gt m$
#
# There are more constraints to have a unique decomposition.
#
# $U$ should be orthonormal: $U^{T}U = I_{m \times m}$
#
# Same for $V$
#
# We are assuming Euclidean inner product but applies to any inner product
#
# $$
# \Sigma =
# \begin{bmatrix}
#   \sigma_{1} & \ldots & 0 \\
#   0 & \sigma_{2} & \ldots & 0\\
#   \vdots & \ddots & \ldots & 0 \\
#   0 & \ldots & \ldots & \ldots & 0
#   \end{bmatrix}
# $$
#
# *clean this section up by reviewing notes*
#
# #### Other types of decompositions
#
# LU Decomposition
# $$
# A_{n \times m} = LU
# $$
#
# QR Decomposition
#
# Chelosky Decomposition
#
# and so on...

# %% [markdown]
# ### Notes from office hours
#
# Questions:
#
# - How to determine if functions are linearly dependent if Wronskian is 0?
# - What is $\mathbf{V}^{\perp}$?
# - How can SVD be used to find over and under determined systems of equations?

# %% [markdown]
# # 20240125 lecture notes

# %% [markdown]
# Delve more into projections today since class ahd questions; they are closely related to least squared regression
#
# - Least squares
#
#   $$
#   \Bigg[ f \Bigg]
#   \approx
#   \Bigg[ u_{1} \Bigg]^{\alpha_{1}}_{n\times 1}
#   \mathrm{+}
#   \Bigg[ u_{2} \Bigg]^{\alpha_{2}}_{n\times 1}
#   \mathrm{+}
#   \ldots
#   \mathrm{+}
#   \Bigg[ u_{r} \Bigg]^{\alpha_{r}}_{n\times 1}
#   $$
# where $n$ is the ambient dimension, $r$ the number of basis vectors and $r\lt n$.  There is a special case where f is equal to the linear combination, but that is not always the case.  Assume that is not the case. $\{u_{i}\}^{r}_{i = 1}$ indpendent vectors.  The goal here is to find optimal $\alpha$ values
#
# See class notes for image.
#
# $f$ is the target and $\hat{f}$ is the approximation
#
# $$
# f = \hat{f} = \sum^{r}_{i = 1}\alpha_{i}u_{i} = U_{\alpha}
# $$
#
# The best approximation is the orthogonal approximation but we'll come back to that.
#
# $$
# f_{n\times 1} = \hat{f}_{n\times 1} + e_{n\times 1} \implies e = f - U_{\alpha}
# $$
# $$
# E(\alpha) = \lVert e \rVert^{2} = \lVert f - U_{\alpha} \lVert^{2}
# $$
#
# Remember that $\langle e, e \rangle = \lVert e \rVert^{2}$. So
#
# $$
# = (f - U_{\alpha})^{T}(f - U_{\alpha})
# $$
#
# Remember $(AB)^{T} = B^{T}A^{T}$
#
# $$
# = f^{T}f - f^{T}U\alpha - \alpha^{T}U^{T}f + \alpha^{T}U^{T}\alpha
# $$
#
# Remember is a is a scaler than the transpose of a scaler is equal to itself
#
# Since all these are scalers we can change whichever we want
#
# $$
# = f^{T}f - 2\alpha^{T}U^{T}f + \alpha^{T}U^{T}\alpha
# $$
#
# The best $\alpha$:
#
# Couldn't keep up transcribe from notes
#
# Need to take the derivate to find the best alpha because the best alpha is the 0 vector.  Go home and work this out.
#
# You end up getting:
#
# $$
# \frac{\partial{E}}{\partial{\alpha}} = -2U^{T}f + 2U^{T}U\alpha = 0
# $$
#
# Solve for $\alpha$
#
# U is independent so it is invertible if it wasn't than you can't do the inverse operation that's in the notes
#
# See notes that prove this is a projector
#
# The projector should be the size of the ambient which it is
#
# Then show $\mathbf{P}^{2} = \mathbf{P}$
#
# It is a projector but is it an othrogonal projector?  Check that it is symmetric which it is.
#
# So P is an othrogonal projector to the space spanned by $U$.
#
# > Least squares is nothing but nothing but the orthongoal projection of the vector to the space given; it's an optimization.
#
# ### Galerkin Projection
#
# $$
# f = \alpha_{1}u_{1} + \ldots + \alpha_{r}u_{r} + e
# $$
#
# $$
# \hat{f} = \alpha_{1}u_{1} + \ldots + \alpha_{r}u_{r}
# $$
#
# $$
# \hat{f}\perp e \implies \langle u_{i}, e\rangle = 0
# $$
#
# $$
# u^{T}_{i}e = 0 \qquad i = 1, 2, \ldots, r
# $$
#
# see notes
#
# Galerkin projection minimizes error
#
# If $U$ is an orthonormal basis $\implies$ than $U^{T}U = I$ than the best $\alpha$ is just $U^{T}f$.
#
# $$
# P = U(U^{T}U)^{-1} U^{T} = UU^{T}
# $$
#
# ### Interpolation
#
# Interpolation is actually an oblique projection
#
# $$
# \begin{bmatrix}
#   \cdot \\
#   \cdot \\
#   \vdots \\
#   \cdot \\
#   \cdot
# \end{bmatrix}_{n \times r}
# \approx
# \Bigg[ U \Bigg]_{n\times r}
# \Bigg[ \alpha \Bigg]_{r \times 1}
# $$
#
# $$
# f \approx \hat{f}
# $$
#
# grab the points equal to $r$
#
# $$
# \mathbf{p} =
# \begin{bmatrix}
#   p_{1} \\
#   \vdots \\
#   p_{r}
# \end{bmatrix}_{r\times 1}
# $$
#
# $\mathbf{p}$ is an integer index vector
#
# $$
# f(\mathbf{p}) =
# \begin{bmatrix}
#   f(p_{1}) \\
#   \vdots \\
#   f(p_{r})
# \end{bmatrix}_{r\times 1}
# $$
#
# See notes for numerical example (this is MATLAB notation we are using)
#
# The error at these points is 0
#
# $$
# f(\mathbf{p}) = \hat{f}(\mathbf{p})
# $$
#
# $$
# f(\mathbf{p}) =
# $$
#
# See notes
#
# LSS makes the whole vector accurate where interpolation only makes the selected points accurate but for LSS you need to know the entire f which can be expensive...
#
# We can select interpolators that are almost as good as othrogonal projection which is good if you are data-poor.
#
# You interpolate on the target function and then do a projection onto the space where the approximate function lives.
#
# We prove this with linear algebra... see notes
#
# The end result:
#
# $$
# \hat{f} = U\alpha = UU^{-1}(p_{1}:)f(p) = U(P^{T}U)^{-1}P^{T}f
# $$
#
# Lets call the projector $\mathbf{Q}$.
#
# $$
# \mathbf{Q} = U(\underline{P}^{T})^{-1}P^{T}
# $$
#
# Leads to $\mathbf{Q}^{2} = \mathbf{Q}$ and $\mathbf{Q}^{T} \neq \mathbf{Q}$

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 100
x = np.linspace(-1, 1, n).reshape(n,1)
f = np.sin(2*x)
U = x**0 * x * x**2 * x**3

fhat_orth = U @ np.linalg.inv(np.transpose(U) @ U) @np.transpose(U)@f # fix this...
# fhat_interp = U*inv(U(p,:))*f(p)
# e_orth = norm(f-fhat_orth)
# e_interp = norm(f-fhat_interp)
plt.plot(x, f)
plt.plot(x, fhat_orth)
plt.show()

# %% [markdown]
# ### Regression
#
# Regression covers both interpolation and projection
#
# $r \leq r' \leq n$ but in our case $r \lt r' \lt n$  SUppose r is 4 and r' is 5
#
# See notes...
#
# We want to approach orthogonal projection error and interpolation is bad against noise so regression is the answer and it also covers if we don't have a lot of data points.
#
# ### Function approximation
#
# $$
# f(x) \approx \sum^{r}_{i = 1}\alpha_{i}u_{i}(x)
# $$
#
# $$
# f(x) \approx \sum^{r}_{i = 1}\alpha_{i}u_{i}(x) + e(x)
# $$
#
# $$
# \langle u(x), u(x) \rangle = \int^{a}_{b}u(x)v(x)dx
# $$
#
# $$
# \langle f(x) \approx \sum^{r}_{i = 1}\alpha_{i}u_{i}(x) + e(x), u_{i}(x) \rangle
# $$
#
# Fourier series... see notes..
#
# This is called FFT

# %% [markdown]
# <table style="width: 100%; background-color: transparent;">
#     <tr>
#         <td style="text-align: left;">
#             <a href="some_link">
#                 <button>&#8592; Previous</button>
#             </a>
#         </td>
#         <td style="text-align: center;">
#             <a href="home_link">
#                 <button><i class="fa fa-home"></i> Home</button>
#             </a>
#         </td>
#         <td style="text-align: right;">
#             <a href="path_to_target_notebook.ipynb">
#                 <button>Next &#8594;</button>
#             </a>
#         </td>
#    </tr>
# </table>
